# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanDaniarAP/MLTask/blob/main/Week2/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = '/content/EconomiesOfScale.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Number of Units  Manufacturing Cost
# 0         1.000000           95.066056
# 1         1.185994           96.531750
# 2         1.191499           73.661311
# 3         1.204771           95.566843
# 4         1.298773           98.777013

# %%
df
# Out:
#      Number of Units  Manufacturing Cost
# 0           1.000000           95.066056
# 1           1.185994           96.531750
# 2           1.191499           73.661311
# 3           1.204771           95.566843
# 4           1.298773           98.777013
# ..               ...                 ...
# 995         8.099710           23.855067
# 996         8.739752           27.536542
# 997         8.780888           25.973787
# 998         8.897700           25.138311
# 999        10.000000           21.547777
#
# [1000 rows x 2 columns]

# %%
df.head(20)
# Out:
#     Number of Units  Manufacturing Cost
# 0          1.000000           95.066056
# 1          1.185994           96.531750
# 2          1.191499           73.661311
# 3          1.204771           95.566843
# 4          1.298773           98.777013
# 5          1.307435          100.000000
# 6          1.339386           94.759756
# 7          1.379044           67.185383
# 8          1.420000           72.886041
# 9          1.473948           61.967696
# 10         1.540898           69.284097
# 11         1.574600           64.552496
# 12         1.620310           77.679377
# 13         1.631997           58.426645
# 14         1.652687           51.440970
# 15         1.695801           60.929036
# 16         1.704214           81.867756
# 17         1.739201           60.572597
# 18         1.760146           74.122601
# 19         1.767002           71.614173

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Number of Units     1000 non-null   float64
#  1   Manufacturing Cost  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
df.describe()
# Out:
#        Number of Units  Manufacturing Cost
# count      1000.000000         1000.000000
# mean          4.472799           40.052999
# std           1.336241           10.595322
# min           1.000000           20.000000
# 25%           3.594214           32.912036
# 50%           4.435958           38.345781
# 75%           5.324780           44.531822
# max          10.000000          100.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Anda memiliki DataFrame 'df' dengan kolom 'Number of Units' dan 'Manufacturing Cost'

# Scatter plot
sns.scatterplot(data=df, x="Number of Units", y="Manufacturing Cost")

# Memberi judul plot
plt.title("Relation")

# Memberi label sumbu x
plt.xlabel("Number Of Units")

# Memberi label sumbu y
plt.ylabel("Manufacturing Cost")

# Menampilkan plot
plt.show()

# %%
# Menggunakan kolom 'Number of Unit' sebagai label (variabel independen)
X = df[['Number of Units']]

# Menggunakan kolom 'Manufacturing Cost' sebagai target (variabel dependen)
y = df['Manufacturing Cost']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Misalnya, Anda memiliki DataFrame yang berisi data Anda.
# Gantilah 'df' dengan nama DataFrame Anda dan pastikan Anda memiliki kolom 'Number Of Units' dan 'Manufacturing Cost'.
# Misalnya, X adalah kolom 'Number Of Units' dan y adalah kolom 'Manufacturing Cost'.

# Contoh DataFrame sederhana
data = {
    'Number Of Units': [10, 20, 30, 40, 50],
    'Manufacturing Cost': [1000, 1500, 2000, 2500, 3000]
}

df = pd.DataFrame(data)
X = df[['Number Of Units']]
y = df['Manufacturing Cost']

# Menggunakan Polynomial Regression dengan derajat dari 1 hingga 8
degrees = list(range(1, 9))
mse_values = []

for degree in degrees:
    # Membuat fitur polynomial sesuai derajat
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X)

    # Melatih model Linear Regression pada fitur polynomial
    model = LinearRegression()
    model.fit(X_poly, y)

    # Memprediksi hasil
    y_pred = model.predict(X_poly)

    # Menghitung Mean Squared Error (MSE)
    mse = mean_squared_error(y, y_pred)
    mse_values.append(mse)

# Visualisasi hasil MSE untuk setiap derajat polynomial
plt.figure(figsize=(10, 6))
plt.plot(degrees, mse_values, marker='o')
plt.title('Mean Squared Error (MSE) for Polynomial Regression')
plt.xlabel('Polynomial Degree')
plt.ylabel('MSE')
plt.xticks(degrees)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
# Membuat data contoh
np.random.seed(0)
X = np.linspace(0, 10, 100)
y = 2 * X - 1 + np.random.randn(100)

# Menginisialisasi plot
plt.figure(figsize=(12, 8))
plt.scatter(X, y, s=20, label='Data')

# Melakukan regresi polinomial untuk derajat 1 hingga 8
for degree in range(1, 9):
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(X.reshape(-1, 1), y)
    y_pred = model.predict(X.reshape(-1, 1))
    plt.plot(X, y_pred, label=f'Degree {degree}')

plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Polynomial Regression')
plt.show()
